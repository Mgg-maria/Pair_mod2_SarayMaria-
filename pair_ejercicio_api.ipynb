# %%
import pandas as pd

# %%
import requests

# %%
# Seleccionamos el tercer endpoint del link. 

url_2011_2022 = "https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2014-01-01T00:00&end_date=2018-12-31T23:59&time_trunc=year&geo_trunc=electric_system&geo_limit=ccaa&geo_ids=7"

# %%
# Hacemos la petición

requests.get(url_2011_2022)
# Out:
# <Response [200]>

# %%
# Hemos hecho la llamada pero ahora hay que almacenar esos datos en una variable

llamada = requests.get(url_2011_2022)

# %%
# Confirmamos que el estado de la llamada ha sido exitoso. El código 200 nos indica que es exitoso

llamada.status_code
# Out:
# 200

# %%
# Mensaje sobre el estado.

llamada.reason
# Out:
# 'OK'

# %%
# Nos devuelve el contenido de la llamada en tipo string.

llamada.content
# Out:
# b'{"data":{"type":"Generaci\\u00f3n por tecnolog\\u00eda","id":"gen1","attributes":{"title":"Generaci\\u00f3n por tecnolog\\u00eda","last-update":"2019-06-12T17:00:43.000+02:00","description":null},"meta":{"cache-control":{"cache":"HIT","expireAt":"2025-03-21T10:03:00"}}},"included":[{"type":"Hidr\\u00e1ulica","id":"10330","groupId":"1","attributes":{"title":"Hidr\\u00e1ulica","description":null,"color":"#0090d1","type":"Renovable","magnitude":null,"composite":false,"last-update":"2019-06-20T14:17:29.000+02:00","values":[{"value":1006208.552,"percentage":0.04482814638697235,"datetime":"2014-01-01T00:00:00.000+01:00"},{"value":700914.375,"percentage":0.03251746074817508,"datetime":"2015-01-01T00:00:00.000+01:00"},{"value":731944.331,"percentage":0.03446238183064846,"datetime":"2016-01-01T00:00:00.000+01:00"},{"value":410077.844,"percentage":0.019173523449433308,"datetime":"2017-01-01T00:00:00.000+01:00"},{"value":768189.817,"percentage":0.035506152699388324,"datetime":"2018-01-01T00:0
# ...

# %%
# Conseguir los datos en formato json

llamada.json()
# Out:
# {'data': {'type': 'Generación por tecnología',
#   'id': 'gen1',
#   'attributes': {'title': 'Generación por tecnología',
#    'last-update': '2019-06-12T17:00:43.000+02:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'HIT',
#     'expireAt': '2025-03-21T10:03:00'}}},
#  'included': [{'type': 'Hidráulica',
#    'id': '10330',
#    'groupId': '1',
#    'attributes': {'title': 'Hidráulica',
#     'description': None,
#     'color': '#0090d1',
#     'type': 'Renovable',
#     'magnitude': None,
#     'composite': False,
#     'last-update': '2019-06-20T14:17:29.000+02:00',
#     'values': [{'value': 1006208.552,
#       'percentage': 0.04482814638697235,
#       'datetime': '2014-01-01T00:00:00.000+01:00'},
#      {'value': 700914.375,
#       'percentage': 0.03251746074817508,
#       'datetime': '2015-01-01T00:00:00.000+01:00'},
#      {'value': 731944.331,
#       'percentage': 0.03446238183064846,
#       'datetime': '2016-01-01T00:00:00.000+01:00'},
# ...

# %%
datos_energia = llamada.json()

# %%
type(datos_energia)
# Out:
# dict

# %% [markdown]
# tipo = datos_energia["type"]

# %%
datos_energia.keys()
# Out:
# dict_keys(['data', 'included'])

# %%
datos_energia["data"]
# Out:
# {'type': 'Generación por tecnología',
#  'id': 'gen1',
#  'attributes': {'title': 'Generación por tecnología',
#   'last-update': '2019-06-12T17:00:43.000+02:00',
#   'description': None},
#  'meta': {'cache-control': {'cache': 'HIT',
#    'expireAt': '2025-03-21T10:03:00'}}}

# %%
# Aquí están los datos que nos interesan

datos_energia["included"]
# Out:
# [{'type': 'Hidráulica',
#   'id': '10330',
#   'groupId': '1',
#   'attributes': {'title': 'Hidráulica',
#    'description': None,
#    'color': '#0090d1',
#    'type': 'Renovable',
#    'magnitude': None,
#    'composite': False,
#    'last-update': '2019-06-20T14:17:29.000+02:00',
#    'values': [{'value': 1006208.552,
#      'percentage': 0.04482814638697235,
#      'datetime': '2014-01-01T00:00:00.000+01:00'},
#     {'value': 700914.375,
#      'percentage': 0.03251746074817508,
#      'datetime': '2015-01-01T00:00:00.000+01:00'},
#     {'value': 731944.331,
#      'percentage': 0.03446238183064846,
#      'datetime': '2016-01-01T00:00:00.000+01:00'},
#     {'value': 410077.844,
#      'percentage': 0.019173523449433308,
#      'datetime': '2017-01-01T00:00:00.000+01:00'},
#     {'value': 768189.817,
#      'percentage': 0.035506152699388324,
#      'datetime': '2018-01-01T00:00:00.000+01:00'}]}},
#  {'type': 'Nuclear',
#   'id': '1695',
#   'groupId': '1',
# ...
